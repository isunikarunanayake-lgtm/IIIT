# %% [markdown]
# # Section A

# %%
name="isuni"
print(name)
# Out:
# isuni

# %%
x=int(input("enter num1"))
y=int(input("enter num2"))
sum=x+y
print(sum)
# Out:
# enter num1 10
# enter num2 12
# 22

# %%
x=input("enter the age")
print(f"I am {x} years old")
# Out:
# enter the age 23
# I am 23 years old

# %%
school="Panadura Balika MV"
print(school)
# Out:
# Panadura Balika MV

# %% [markdown]
# # Section B

# %%
x=int(input("Birth Year"))
y=int(input("Current Year"))
age=y-x
print(f"Your age : {age}")
# Out:
# Birth Year 2005
# Current Year 2025
# Your age : 20

# %%
x=int(input("Enter the temperature"))
Temp=(x*9/5)+32
print(f"{x} celcius is {Temp} in Farenheit")
# Out:
# Enter the temperature 24
# 24 celcius is 75.2 in Farenheit

# %%
x=int(input("Enter the radius"))
Area=3.14*x**2
print(Area)
# Out:
# Enter the radius 7
# 153.86

# %%
day=int(input("Enter the day"))
week=day//7
rdays=day%7
print(f"This is {week} week")
print(f"There are {rdays} remaining days")
# Out:
# Enter the day 31
# This is 4 week
# There are 3 remaining days

# %%
x=int(input("Birth Year"))
y=int(input("Current Year"))
age=y-x
print(f"Your age : {age}")
# Out:
# Birth Year 2005
# Current Year 2025
# Your age : 20

# %% [markdown]
# # Section C

# %%
x=int(input("Enter the hours worked"))
y=200
tot=x*y
print(f"Your total payment is Rs.{tot}")
# Out:
# Enter the hours worked 157
# Your total payment is Rs.31400
