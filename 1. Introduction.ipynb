# %% [markdown]
# # IIT python clsss

# %% [markdown]
# ## Week 01 homework

# %% [markdown]
# ### Very first command

# %%
print("hello sri lanka")
# Out:
# hello sri lanka

# %%
Print("isuni")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 Print("isuni")
#
# NameError: name 'Print' is not defined

# %%
print('hiiiii')
# Out:
# hiiiii

# %%
print("my name is Isuni Karunanayake,")
print("I am an undergraduate in university of colombo,")
print("I am learning python programming these days.")
# Out:
# my name is Isuni Karunanayake,
# I am an undergraduate in university of colombo,
# I am learning python programming these days.
