# %%
num1=int(input("enter the num1"))
# Out:
# enter the num1 35

# %%
num2=int(input("enter the num2"))
# Out:
# enter the num2 45

# %%
sum=num1+num2
print(sum)
# Out:
# 80

# %%
name1=(input("enter the name1"))
name2=(input("enter the name2"))
sub1=int(input("enter sub1 marks"))
sub2=int(input("enter sub2 marks"))
sub3=int(input("enter sub3 marks"))
sum=sub1+sub2+sub3
average=sum/3
print(name)
print(sub1)
print(sub2)
print(sub3)
print(sum)
print(average)
# Out:
# enter the name1 Isuni
# enter the name2 Karunanayake
# enter sub1 marks 85
# enter sub2 marks 95
# enter sub3 marks 87
# Isuni
# 85
# 95
# 87
# 267
# 89.0

# %%
print(name1," ",name2,sub1)
# Out:
# Isuni   Karunanayake 85
