# %%
Name=input("Enter the name")
marks=int(input("Enter the marks"))
print(Name)
if marks>80:
    print("A")
elif marks>=60:
    print("B")
elif marks>=40:
    print("C")
else:
    print("Fail")
# Out:
# Enter the name Isuni
# Enter the marks 78
# Isuni
# B
