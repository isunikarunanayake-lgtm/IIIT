# %% [markdown]
# ### Variable

# %%
x=10
y="sri lanka"
print(x)
print(type(x))
print(y)
print(type(y))
# Out:
# 10
# <class 'int'>
# sri lanka
# <class 'str'>

# %%
if=10
print(if)
if is a keyword so this is a syntax error

# %% [markdown]
# ### Arithmatic Operations

# %% [markdown]
# ## Substraction

# %%
5-2
# Out:
# 3

# %% [markdown]
# ## Multiplication

# %%
5*2
# Out:
# 10

# %% [markdown]
# ## Division

# %%
4/2
# Out:
# 2.0

# %% [markdown]
# ## Floor Division

# %%
5//2
# Out:
# 2

# %% [markdown]
# ## Modules

# %%
5%2
# Out:
# 1

# %% [markdown]
# ## Power

# %%
5**2
# Out:
# 25

# %%
a=2
b=5
a+=b
a
# Out:
# 7

# %%
a//=b
a
# Out:
# 1

# %%
a/=b
a
# Out:
# 0.2

# %% [markdown]
# ### Comaprison

# %% [markdown]
# ## Equal

# %%
a==b
# Out:
# False

# %% [markdown]
# ## Not equal

# %%
a!=b
# Out:
# True

# %%
a>=b
# Out:
# False

# %%
a<=b
# Out:
# True

# %% [markdown]
# ### logical operator

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False
