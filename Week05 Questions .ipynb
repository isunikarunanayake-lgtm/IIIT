# %%
def hi():
    print("Hello world")

# %%
hi()
# Out:
# Hello world

# %%
def greet(name):
    print(f"Hello {name}")
greet("Isuni")
# Out:
# Hello Isuni

# %%
def calculate(a,b):
    return a+b

# %%
calculate(12,23)
# Out:
# 35

# %%
def calculate(num):
    if num%2==0:
        print("Even number")
    else:
       print("Odd number")

# %%
calculate(46)
# Out:
# Even number

# %%
def calculate(a):
    return a**2

# %%
calculate(49)
# Out:
# 2401

# %%
def calculate(*args):
    return sum(args)

# %%
calculate(1,2,34)
# Out:
# 37

# %%
def calculate(a):
    return (a*9/5)+32

# %%
def calculate(a):
    return 22/7*a**2

# %%
calculate(7)
# Out:
# 154.0
